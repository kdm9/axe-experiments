# %%
bvz = read.delim('../data//assessments//3176_nested-pe_axe.tab', row.names=1)

# %%
m = as.matrix(bvz)
mn = m / rowSums(m)

# %%
(sum(m) - sum(diag(m)) )/ sum(m)
# Out:
# [1] 0.01470384

# %%
par( mar = par( "mar" ) + c( 2, 4, 0, 0 ) )
image( t(mn), xaxt= "n", yaxt= "n" )
axis( 1, at=seq(0,1,length.out=ncol( m ) ), labels= colnames( m ), las= 2 )
axis( 2, at=seq(0,1,length.out=nrow( m ) ), labels= rownames( m ), las= 2)
# Out:
# plot without title
